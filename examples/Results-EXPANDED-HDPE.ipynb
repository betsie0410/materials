# %%
import sys
sys.path.append('../../src')

import sys
sys.path.append('../src')

# %%
import pandas
import numpy
from energiapy.components.temporal_scale import TemporalScale
from energiapy.components.resource import Resource, VaryingResource
from energiapy.components.process import Process, VaryingProcess
from energiapy.components.material import Material
from energiapy.components.location import Location
from energiapy.components.network import Network
from energiapy.components.scenario import Scenario
from energiapy.components.transport import Transport
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.utils.nsrdb_utils import fetch_nsrdb_data
from energiapy.plot import plot_results, plot_scenario
from energiapy.plot.plot_results import CostY, CostX
from energiapy.model.solve import solve
from itertools import product



from energiapy.components.result import Result
import pandas
from itertools import product
from matplotlib import rc
import matplotlib.pyplot as plt
from energiapy.model.solve import solve
from energiapy.plot.plot_results import CostY, CostX
from energiapy.components.location import Location
from energiapy.plot import plot_results, plot_scenario
from energiapy.utils.nsrdb_utils import fetch_nsrdb_data
from energiapy.model.formulate import formulate, Constraints, Objective
from energiapy.model.bounds import CapacityBounds
from energiapy.utils.data_utils import get_data, make_henry_price_df, remove_outliers, load_results
from energiapy.components.transport import Transport
from energiapy.components.scenario import Scenario
from energiapy.components.network import Network
from energiapy.components.location import Location
from energiapy.components.material import Material

from energiapy.conversion.photovoltaic import solar_power_output
from energiapy.conversion.windmill import wind_power_output

from energiapy.utils.data_utils import load_results
from energiapy.plot import plot_results, plot_scenario
from energiapy.plot.plot_results import CostY, CostX

# %%
results_cost = load_results(filename='res7_cost.pkl')
results_gwp_2 = load_results(filename='res7_gwp_2.pkl')
results_gwp_4 = load_results(filename='res7_gwp_4.pkl')
results_gwp_6 = load_results(filename='res7_gwp_6.pkl')
results_gwp_8 = load_results(filename='res7_gwp_8.pkl')
results_gwp_max = load_results(filename='res7_gwp_max.pkl')
results_nobau = load_results (filename= 'res7_nobau.pkl')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 4
#       2 results_gwp_2 = load_results(filename='res7_gwp_2.pkl')
#       3 results_gwp_4 = load_results(filename='res7_gwp_4.pkl')
# ----> 4 results_gwp_6 = load_results(filename='res7_gwp_6.pkl')
#       5 results_gwp_8 = load_results(filename='res7_gwp_8.pkl')
#       6 results_gwp_max = load_results(filename='res7_gwp_max.pkl')
#
# File c:\Users\betsie_0410\energiapy\examples\../src\energiapy\utils\data_utils.py:285, in load_results(filename)
#     276 """loads saved results
#     277
#     278 Args:
#    (...)
#     282     Result: a energiapy result type object
#     283 """
#     284 file_ = open(filename, 'rb')
# --> 285 results_dict = pickle.load(file_)
#     286 if results_dict['output']['termination'] != 'optimal':
#     287     print('WARNING: Loading non-optimal results')
#
# MemoryError:

# %%
results_list = [results_cost, results_gwp_2, results_gwp_4, results_gwp_6, results_gwp_8, results_gwp_max]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results_list = [results_cost, results_gwp_2, results_gwp_4, results_gwp_6, results_gwp_8, results_gwp_max]
#
# NameError: name 'results_cost' is not defined

# %%
results_cost.output['objective']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 results_cost.output['objective']
#
# NameError: name 'results_cost' is not defined

# %%
for i in results_nobau.output['Cap_P_M'].keys():
    if results_nobau.output['Cap_P_M'][i] > 0:
        print(i, results_nobau.output['Cap_P_M'][i])
# Out:
# ('HO', 'Compression molding', 'HDPE CM', 0) 0.09092579908675799
# ('HO', 'Extrusion', 'HDPE E', 0) 0.034679412841796875
# ('HO', 'Grid', 'C', 0) 0.7116751033789954
# ('HO', 'HDPE BAU', 'HDPE BAU', 0) 0.40969724086198767
# ('HO', 'Injection molding', 'HDPE IM', 0) 0.24935958904105812
# ('HO', 'car_prod', 'D', 0) 148.40182648401827

# %%
results_nobau.output['objective']/results_gwp_6.output['objective']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 results_nobau.output['objective']/results_gwp_6.output['objective']
#
# NameError: name 'results_gwp_6' is not defined

# %%
for i in results_cost.output['Cap_P_M'].keys():
    if results_cost.output['Cap_P_M'][i] > 0:
        print(i, results_cost.output['Cap_P_M'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for i in results_cost.output['Cap_P_M'].keys():
#       2     if results_cost.output['Cap_P_M'][i] > 0:
#       3         print(i, results_cost.output['Cap_P_M'][i])
#
# NameError: name 'results_cost' is not defined

# %%
for i in results_gwp_2.output['Cap_P_M'].keys():
    if results_gwp_2.output['Cap_P_M'][i] >0:
        print(i, results_gwp_2.output['Cap_P_M'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for i in results_gwp_2.output['Cap_P_M'].keys():
#       2     if results_gwp_2.output['Cap_P_M'][i] >0:
#       3         print(i, results_gwp_2.output['Cap_P_M'][i])
#
# NameError: name 'results_gwp_2' is not defined

# %%
for i in results_gwp_4.output['Cap_P_M'].keys():
    if results_gwp_4.output['Cap_P_M'][i] >0:
        print(i, results_gwp_4.output['Cap_P_M'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 for i in results_gwp_4.output['Cap_P_M'].keys():
#       2     if results_gwp_4.output['Cap_P_M'][i] >0:
#       3         print(i, results_gwp_4.output['Cap_P_M'][i])
#
# NameError: name 'results_gwp_4' is not defined

# %%
for i in results_gwp_6.output['Cap_P_M'].keys():
    if results_gwp_6.output['Cap_P_M'][i] >0:
        print(i, results_gwp_6.output['Cap_P_M'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 for i in results_gwp_6.output['Cap_P_M'].keys():
#       2     if results_gwp_6.output['Cap_P_M'][i] >0:
#       3         print(i, results_gwp_6.output['Cap_P_M'][i])
#
# NameError: name 'results_gwp_6' is not defined

# %%
for i in results_gwp_8.output['Cap_P_M'].keys():
    if results_gwp_8.output['Cap_P_M'][i] >0:
        print(i, results_gwp_8.output['Cap_P_M'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 for i in results_gwp_8.output['Cap_P_M'].keys():
#       2     if results_gwp_8.output['Cap_P_M'][i] >0:
#       3         print(i, results_gwp_8.output['Cap_P_M'][i])
#
# NameError: name 'results_gwp_8' is not defined

# %%
for i in results_gwp_max.output['Cap_P_M'].keys():
    if results_gwp_max.output['Cap_P_M'][i] >0:
        print(i, results_gwp_max.output['Cap_P_M'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 for i in results_gwp_max.output['Cap_P_M'].keys():
#       2     if results_gwp_max.output['Cap_P_M'][i] >0:
#       3         print(i, results_gwp_max.output['Cap_P_M'][i])
#
# NameError: name 'results_gwp_max' is not defined

# %%
plot_results.schedule(results=results_gwp_6, y_axis= 'P', component= 'HDPE BAU', location='HO')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plot_results.schedule(results=results_gwp_6, y_axis= 'P', component= 'HDPE BAU', location='HO')
#
# NameError: name 'results_gwp_6' is not defined

# %%
plot_results.schedule(results=results_gwp_6, y_axis= 'P', component= 'HDPE CO2', location='HO')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plot_results.schedule(results=results_gwp_6, y_axis= 'P', component= 'HDPE CO2', location='HO')
#
# NameError: name 'results_gwp_6' is not defined

# %%
plot_results.schedule(results=results_gwp_6, y_axis= 'S', component= 'Car', location='HO')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plot_results.schedule(results=results_gwp_6, y_axis= 'S', component= 'Car', location='HO')
#
# NameError: name 'results_gwp_6' is not defined

# %%
results_cost.output['S_network']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 results_cost.output['S_network']
#
# NameError: name 'results_cost' is not defined

# %%
results_gwp_8.output['S_network']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 results_gwp_8.output['S_network']
#
# NameError: name 'results_gwp_8' is not defined

# %%
results_gwp_max.output['S_network']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 results_gwp_max.output['S_network']
#
# NameError: name 'results_gwp_max' is not defined

# %%
[i.output['global_warming_potential_network'][0]/i.output['S_network'][('Car', 0)] for i in results_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 [i.output['global_warming_potential_network'][0]/i.output['S_network'][('Car', 0)] for i in results_list]
#
# NameError: name 'results_list' is not defined

# %%
results_cost.output['S_network']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 results_cost.output['S_network']
#
# NameError: name 'results_cost' is not defined

# %%
results_cost.output['S_network']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 results_cost.output['S_network']
#
# NameError: name 'results_cost' is not defined

# %%
[i.output['S_network'][('CO2_Vent', 0)]/i.output['S_network'][('Car', 0)] for i in results_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 [i.output['S_network'][('CO2_Vent', 0)]/i.output['S_network'][('Car', 0)] for i in results_list]
#
# NameError: name 'results_list' is not defined

# %%
results_cost.output['global_warming_potential_network'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 results_cost.output['global_warming_potential_network'][0]
#
# NameError: name 'results_cost' is not defined

# %%
cost = [i.output['objective'] for i in results_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 cost = [i.output['objective'] for i in results_list]
#
# NameError: name 'results_list' is not defined

# %%
cost = [i*100/min(cost) for i in cost]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 cost = [i*100/min(cost) for i in cost]
#
# NameError: name 'cost' is not defined

# %%
cost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cost
#
# NameError: name 'cost' is not defined

# %%
gwp= [i.output['global_warming_potential_network'][0] for i in results_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 gwp= [i.output['global_warming_potential_network'][0] for i in results_list]
#
# NameError: name 'results_list' is not defined

# %%
gwp = [i/max(gwp) for i in gwp]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 gwp = [i/max(gwp) for i in gwp]
#
# NameError: name 'gwp' is not defined

# %%
rc('font', **{'family': 'serif',
    'serif': ['Computer Modern'], 'size': 16})
fig, ax = plt.subplots(figsize=(10,5))
y_ = cost
x_ = [0, 2, 4, 6, 8, 9.07]
ax.plot(x_, y_, color='red')
ax.scatter(x_, y_, color='red')
plt.title(f'Trade-off between cost and emission reduction')
plt.ylabel("Cost compared to base case (%)")
plt.xlabel("reduction in emission (%)")
ax.set_xticks(x_)
ax.set_xticklabels(x_)
plt.grid(alpha=0.3)
plt.rcdefaults()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 rc('font', **{'family': 'serif',
#       2     'serif': ['Computer Modern'], 'size': 16})
#       3 fig, ax = plt.subplots(figsize=(10,5))
# ----> 4 y_ = cost
#       5 x_ = [0, 2, 4, 6, 8, 9.07]
#       6 ax.plot(x_, y_, color='red')
#
# NameError: name 'cost' is not defined
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
results_cost.output['global_warming_potential_material']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 results_cost.output['global_warming_potential_material']
#
# NameError: name 'results_cost' is not defined

# %%
[
  [i.output['global_warming_potential_material'][('HO', 'LiI', 0)] for i in results_list],
  [i.output['global_warming_potential_material'][('HO', 'WF', 0)] for i in results_list],
  [i.output['global_warming_potential_material'][('HO', 'GridPower', 0)] for i in results_list],
  [i.output['global_warming_potential_resource_consumption'][('HO', 'Natural Gas', 0)] for i in results_list],
  [i.output['global_warming_potential_resource_consumption'][('HO', 'Oil', 0)] for i in results_list],
  [i.output['global_warming_potential_resource_discharge'][('HO', 'CO2_Vent', 0)]for i in results_list] 
  ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 [
# ----> 2   [i.output['global_warming_potential_material'][('HO', 'LiI', 0)] for i in results_list],
#       3   [i.output['global_warming_potential_material'][('HO', 'WF', 0)] for i in results_list],
#       4   [i.output['global_warming_potential_material'][('HO', 'GridPower', 0)] for i in results_list],
#       5   [i.output['global_warming_potential_resource_consumption'][('HO', 'Natural Gas', 0)] for i in results_list],
#       6   [i.output['global_warming_potential_resource_consumption'][('HO', 'Oil', 0)] for i in results_list],
#       7   [i.output['global_warming_potential_resource_discharge'][('HO', 'CO2_Vent', 0)]for i in results_list]
#       8   ]
#
# NameError: name 'results_list' is not defined

# %%
rc('font', **{'family': 'serif',
'serif': ['Computer Modern'], 'size': font_size})
rc('text', usetex=usetex)
fig, ax = plt.subplots(figsize=fig_size)
y_ = [100*results.output['Cap_P'][i]/results.components['processes'][i[1]]
['prod_max'] for i in results.output['Cap_P'].keys() if location in i]

title = f"Capacity utilization in {results.components['locations'][location]['label']}"
plt.ylabel("\%")
# results.components['processes'][i[1]]['label']
# x_ = [f"${i[1].split('_')[0]}_{{{i[1].split('_')[1]}}}$" for i in results.output[y_axis].keys() if location in i]
x_ = [i[1] for i in results.output['Cap_P'].keys() if location in i]
ax.bar(x_, y_, linewidth=0.5, color=color)
plt.xticks(rotation=90)
plt.grid(alpha=0.3)
plt.title(title)
plt.rcdefaults()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 rc('font', **{'family': 'serif',
# ----> 2 'serif': ['Computer Modern'], 'size': font_size})
#       3 rc('text', usetex=usetex)
#       4 fig, ax = plt.subplots(figsize=fig_size)
#
# NameError: name 'font_size' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

# Your data
data = [
    [140691.4444615116, 154321.53183092162, 153937.93048675952, 193044.77754758202, 344080.3915170005, 526848.8239172742],
    [2458040.8103281595, 2380663.4409507317, 2382613.168256611, 2729660.9955549473, 3552029.153951385, 4580628.917185124],
    [4103951.471118176, 3986642.743552084, 3835194.681881987, 3482722.093175227, 2823294.259255325, 2109122.2590269246],
    [1047569.9522268848, 1017625.860783059, 978967.402015911, 888995.6527124952, 720670.8590744416, 538372.1322434429],
    [6658525.5187464515, 6581350.035826762, 6481714.846364667, 6249828.926078061, 5816002.197332537, 5346160.181749119]
]

# Transpose the data for plotting
data_transposed = np.array(data)

# Create stacked bar plot
rc('font', **{'family': 'serif',
           'serif': ['Computer Modern'], 'size': 16})
fig, ax = plt.subplots(figsize = (9,6))
bars = ax.bar(np.arange(len(data[0])), data_transposed[0], label='LiI material')
labels = ['WF material', 'NG purchase', 'Oil purchase', 'CO2 emission']
for i in range(1, len(data)):
    bars = ax.bar(np.arange(len(data[0])), data_transposed[i], bottom=np.sum(data_transposed[:i], axis=0), label=labels[i-1])

# Add labels, title, and legend
ax.set_xlabel('Scenarios')
ax.set_ylabel('CO2 equivalents')
ax.set_title('Contribution to GWP')

xtick_positions = np.arange(len(data[0]))
xtick_labels = ['Base', '-2%', '-4%', '-6%', '-8%', '-9.07%']
ax.set_xticks(xtick_positions)
ax.set_xticklabels(xtick_labels)

ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.grid(zorder=0, alpha = 0.3)
plt.rcdefaults()

# Show the plot
plt.show()

# %%
prod_li = [results_gwp_8.output['P'][('HO', 'LiI_d',i , j, k)] for i, j, k in product(range(1), range(365), range(24))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 prod_li = [results_gwp_8.output['P'][('HO', 'LiI_d',i , j, k)] for i, j, k in product(range(1), range(365), range(24))]
#
# Cell In[44], line 1, in <listcomp>(.0)
# ----> 1 prod_li = [results_gwp_8.output['P'][('HO', 'LiI_d',i , j, k)] for i, j, k in product(range(1), range(365), range(24))]
#
# NameError: name 'results_gwp_8' is not defined

# %%
prod_wf = [results_gwp_8.output['P'][('HO', 'WF',i , j, k)] for i, j, k in product(range(1), range(365), range(24))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 prod_wf = [results_gwp_8.output['P'][('HO', 'WF',i , j, k)] for i, j, k in product(range(1), range(365), range(24))]
#
# Cell In[45], line 1, in <listcomp>(.0)
# ----> 1 prod_wf = [results_gwp_8.output['P'][('HO', 'WF',i , j, k)] for i, j, k in product(range(1), range(365), range(24))]
#
# NameError: name 'results_gwp_8' is not defined

# %%
rc('font', **{'family': 'serif',
    'serif': ['Computer Modern'], 'size': 16})
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(prod_li[24*6: 24*7], label = 'Power Generated (WF)')
ax.plot(prod_wf[24*6: 24*7], label = 'Power discharged (LiI)')
ax.set_ylabel("MW")

ax2 = ax.twinx()

ax2.plot(prod_ocm[24*6: 24*7], color = 'green', linestyle = '--' , label = 'OCM')
ax2.plot(prod_bau[24*6: 24*7], color = 'red', linestyle = '--', label = 'BAU')
ax.set_ylabel("tons")

plt.title(f'Optimal schedule for day 6')
plt.ylabel
plt.xlabel("Hour")
plt.grid(alpha=0.3)
ax.legend(loc='upper center', bbox_to_anchor=(0.3, -0.10), ncol=1)
ax2.legend(loc='upper center', bbox_to_anchor=(0.7, -0.10), ncol=1)

plt.rcdefaults()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       1 rc('font', **{'family': 'serif',
#       2     'serif': ['Computer Modern'], 'size': 16})
#       3 fig, ax = plt.subplots(figsize=(10,5))
# ----> 4 ax.plot(prod_li[24*6: 24*7], label = 'Power Generated (WF)')
#       5 ax.plot(prod_wf[24*6: 24*7], label = 'Power discharged (LiI)')
#       6 ax.set_ylabel("MW")
#
# NameError: name 'prod_li' is not defined
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# WARNING:matplotlib.font_manager:findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
