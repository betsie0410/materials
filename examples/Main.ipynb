# %%
import sys
sys.path.append('src')
from Algo import Algo
from Instance import Instance
import time
import os



instance_obj = Instance('USA', 25, 321.869, 4)
#instance_obj.create_instance()
instance_obj.read_instance()

algo_obj = Algo(1, 1, 10, 0.05, 0.5, instance_obj)

# Solve deterministic instance with reported mean values
algo_obj.solve_theo_ev_instance()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('src')
# ----> 3 from Algo import Algo
#       4 from Instance import Instance
#       5 import time
#
# ModuleNotFoundError: No module named 'Algo'
