# %%
# !pip install amplpy

# %%
# !python -m amplpy.modules install gurobi
# Out:
# $ c:\Users\betsie_0410\energiapy\.conda\python.exe -m pip install -i https://pypi.ampl.com ampl_module_base ampl_module_gurobi
# Looking in indexes: https://pypi.ampl.com
#
# ...
#
# ...
#
# Imported ampl_module_base.
# Imported ampl_module_base.
# Imported ampl_module_gurobi.

# %%
import os

os.chdir(r"C:\Users\betsie_0410\Downloads\AMPL\Partial_domination")
os.getcwd()
# Out:
# 'C:\\Users\\betsie_0410\\Downloads\\AMPL\\Partial_domination'

# %%
os.makedirs("results/BD0", exist_ok=True)

# %%
from amplpy import AMPL

ampl = AMPL()
ampl.read(r"C:\Users\betsie_0410\Downloads\AMPL\Partial_domination\partialdomination.run")
# Out:
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# ...

# %%
import os
os.environ["GRB_LICENSE_FILE"] = r"C:\Users\betsie_0410\gurobi.lic"

from amplpy import AMPL

# 1. Set working directory
os.chdir(r"C:\Users\betsie_0410\Downloads\AMPL\Partial_domination")
print("Current working directory:", os.getcwd())

# 2. Create results folder if it doesn't exist
os.makedirs("results/BD0", exist_ok=True)

# 3. Initialize AMPL
ampl = AMPL()

# 4. Read the .run file
ampl.read("partialdomination.run")
# Out:
# Current working directory: C:\Users\betsie_0410\Downloads\AMPL\Partial_domination
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
#
# CreateProcess("..\gurobi.exe") failure!
# Error code 2.
# f = 0
# ...
